# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set(color_codes=False)

# %%
df = pd.read_excel("C:/Users/PC/Downloads/ipqdata.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df
# Out:
#     INTERFACE  IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# 0           1       3.5000        3.25      2.50        3.2857
# 1           1       3.3333        2.50      1.00        2.5714
# 2           1       3.1667        1.75      1.00        2.1429
# 3           1       3.8333        3.75      3.50        3.8571
# 4           1       4.0000        4.75      3.75        4.4286
# 5           1       3.0000        3.00      3.00        3.0000
# 6           1       3.5000        3.25      1.75        2.9286
# 7           1       3.6667        4.00      2.50        3.5714
# 8           1       3.6667        2.25      1.50        2.7857
# 9           1       3.5000        3.50      1.50        3.0714
# 10          1       3.5000        2.00      2.25        2.8571
# 11          1       4.3333        3.75      1.75        3.7143
# 12          1       3.5000        2.25      1.50        2.5714
# 13          1       3.6667        3.75      2.00        3.3571
# ...

# %%
data = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

# %%
data
# Out:
#     INTERFACE  IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# 0           1       3.5000        3.25      2.50        3.2857
# 1           1       3.3333        2.50      1.00        2.5714
# 2           1       3.1667        1.75      1.00        2.1429
# 3           1       3.8333        3.75      3.50        3.8571
# 4           1       4.0000        4.75      3.75        4.4286
# 5           1       3.0000        3.00      3.00        3.0000
# 6           1       3.5000        3.25      1.75        2.9286
# 7           1       3.6667        4.00      2.50        3.5714
# 8           1       3.6667        2.25      1.50        2.7857
# 9           1       3.5000        3.50      1.50        3.0714
# 10          1       3.5000        2.00      2.25        2.8571
# 11          1       4.3333        3.75      1.75        3.7143
# 12          1       3.5000        2.25      1.50        2.5714
# 13          1       3.6667        3.75      2.00        3.3571
# ...

# %%
data_long = pd.melt(data, "INTERFACE", var_name="IPQ", value_name="values")

# %%
data_long
# Out:
#      INTERFACE           IPQ  values
# 0            1   IPQ_SPATIAL  3.5000
# 1            1   IPQ_SPATIAL  3.3333
# 2            1   IPQ_SPATIAL  3.1667
# 3            1   IPQ_SPATIAL  3.8333
# 4            1   IPQ_SPATIAL  4.0000
# 5            1   IPQ_SPATIAL  3.0000
# 6            1   IPQ_SPATIAL  3.5000
# 7            1   IPQ_SPATIAL  3.6667
# 8            1   IPQ_SPATIAL  3.6667
# 9            1   IPQ_SPATIAL  3.5000
# 10           1   IPQ_SPATIAL  3.5000
# 11           1   IPQ_SPATIAL  4.3333
# 12           1   IPQ_SPATIAL  3.5000
# 13           1   IPQ_SPATIAL  3.6667
# 14           1   IPQ_SPATIAL  4.1667
# 15           1   IPQ_SPATIAL  3.1667
# 16           1   IPQ_SPATIAL  3.1667
# 17           3   IPQ_SPATIAL  3.3333
# 18           3   IPQ_SPATIAL  3.8333
# 19           3   IPQ_SPATIAL  3.3333
# 20           3   IPQ_SPATIAL  3.3333
# 21           3   IPQ_SPATIAL  3.3333
# 22           3   IPQ_SPATIAL  3.6667
# 23           3   IPQ_SPATIAL  4.5000
# ...

# %%
sns.factorplot("IPQ", hue="INTERFACE", y="value", data=data_long, kind="box", notch=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8276122c51fd> in <module>()
# ----> 1 sns.factorplot("IPQ", hue="INTERFACE", y="value", data=data_long, kind="box", notch=True)
#
# c:\program files\python36\lib\site-packages\seaborn\categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
#    3493     hue_order = p.hue_names
#
# ...

# %%
sns.factorplot("IPQ", hue="INTERFACE", y="values", data=data_long, kind="box", notch=True)

# %%
plt.show()

# %%
data.corr(method='spearman', min_periods=1)
# Out:
#               INTERFACE  IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# INTERFACE      1.000000     0.240376    0.217837  0.263804      0.317928
# IPQ_SPATIAL    0.240376     1.000000    0.263455  0.431308      0.677853
# IPQ_INVOLV     0.217837     0.263455    1.000000  0.439953      0.767169
# IPQ_REAL       0.263804     0.431308    0.439953  1.000000      0.738481
# IPQ_PRESENCE   0.317928     0.677853    0.767169  0.738481      1.000000

# %%
test_data = data.groupby('INTERFACE')

# %%
test_data

# %%
plt.show()

# %%
test_data.corr(method="spearman", min_periods=1)
# Out:
#                         IPQ_INVOLV  IPQ_PRESENCE  IPQ_REAL  IPQ_SPATIAL
# INTERFACE
# 1         IPQ_INVOLV      1.000000      0.851617  0.538183     0.595279
#           IPQ_PRESENCE    0.851617      1.000000  0.794776     0.788680
#           IPQ_REAL        0.538183      0.794776  1.000000     0.535399
#           IPQ_SPATIAL     0.595279      0.788680  0.535399     1.000000
# 2         IPQ_INVOLV      1.000000      0.394917 -0.077737    -0.532039
#           IPQ_PRESENCE    0.394917      1.000000  0.586266     0.246087
#           IPQ_REAL       -0.077737      0.586266  1.000000     0.208396
#           IPQ_SPATIAL    -0.532039      0.246087  0.208396     1.000000
# 3         IPQ_INVOLV      1.000000      0.827956  0.626012     0.182446
#           IPQ_PRESENCE    0.827956      1.000000  0.714198     0.524329
#           IPQ_REAL        0.626012      0.714198  1.000000     0.191020
#           IPQ_SPATIAL     0.182446      0.524329  0.191020     1.000000

# %%
test_data.mean()
# Out:
#            IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# INTERFACE
# 1             3.487185    2.846154  2.173077      3.016477
# 2             3.916675    3.250000  2.562500      3.446437
# 3             3.696071    3.176471  2.632353      3.344541

# %%
test_data.std()
# Out:
#            IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# INTERFACE
# 1             0.382744    0.824854  0.826950      0.585996
# 2             0.530545    0.677003  0.704154      0.353315
# 3             0.387468    0.759136  0.638098      0.513372

# %%
data
# Out:
#     INTERFACE  IPQ_SPATIAL  IPQ_INVOLV  IPQ_REAL  IPQ_PRESENCE
# 0           1       3.5000        3.25      2.50        3.2857
# 1           1       3.3333        2.50      1.00        2.5714
# 2           1       3.1667        1.75      1.00        2.1429
# 3           1       3.8333        3.75      3.50        3.8571
# 4           1       4.0000        4.75      3.75        4.4286
# 5           1       3.0000        3.00      3.00        3.0000
# 6           1       3.5000        3.25      1.75        2.9286
# 7           1       3.6667        4.00      2.50        3.5714
# 8           1       3.6667        2.25      1.50        2.7857
# 9           1       3.5000        3.50      1.50        3.0714
# 10          1       3.5000        2.00      2.25        2.8571
# 11          1       4.3333        3.75      1.75        3.7143
# 12          1       3.5000        2.25      1.50        2.5714
# 13          1       3.6667        3.75      2.00        3.3571
# ...

# %%
data_long.boxplot(by='INTERFACE', notch=True)

# %%
plt.show()

# %%
data.boxplot(by='INTERFACE', notch=True, meanline=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3E0439F98>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3DFC095F8>]], dtype=object)

# %%
plt.show()

# %%
data.boxplot(by='INTERFACE', notch=True, meanline=False, showmeans=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3DF97E3C8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3DF666828>]], dtype=object)

# %%
plt.show()

# %%
sns.set(color_codes=True)

# %%
data.boxplot(by='INTERFACE', notch=True, meanline=False, showmeans=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3DFF9A5F8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3DFF1CE10>]], dtype=object)

# %%
plt.show()

# %%
data.boxplot(by='INTERFACE', notch=True, meanline=False, showmeans=True, marker='+')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0e25d9fcb4ef> in <module>()
# ----> 1 data.boxplot(by='INTERFACE', notch=True, meanline=False, showmeans=True, marker='+')
#
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2065     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2066                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2067                  return_type=return_type, **kwds)
#    2068     plt.draw_if_interactive()
#    2069     return ax
#
# c:\program files\python36\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
# ...

# %%
flierprops = dict(marker='o')

# %%
data.boxplot(by='INTERFACE', notch=True, meanline=False, showmeans=True, flierprops=flierprops)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3E03A8240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3E04D94E0>]], dtype=object)

# %%
plt.show()

# %%
flierprops = dict(marker='+', markerfacecolor='red', markersize=8,
                  linestyle='none')

# %%
data.boxplot(by='INTERFACE', flierprops=flierprops, notch=True, showmeans=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3E0729908>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3E0615EF0>]], dtype=object)

# %%
plt.show()
